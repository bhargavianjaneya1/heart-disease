# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavianjaneya1/heart-disease/blob/main/Surface_crack_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/arunrk7/surface-crack-detection")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: bhargavianjaneya
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/arunrk7/surface-crack-detection
# ...
# 100%|██████████| 233M/233M [00:01<00:00, 168MB/s]

# %%
dataset="/content/surface-crack-detection/Positive"

# %%
#system cant understand images so we converting into numericals
images=[]#numerical representation
labels=[]#for image positive=1 else negative=0

# %%
import numpy as np
import os

# %%
for filename in os.listdir(dataset):
   print(img_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/surface-crack-detection/Positive/03904.jpg
# /content/surface-crack-detection/Positive/15417_1.jpg
# /content/surface-crack-detection/Positive/04220.jpg
# /content/surface-crack-detection/Positive/01315.jpg
# /content/surface-crack-detection/Positive/09995.jpg
# /content/surface-crack-detection/Positive/05276.jpg
# /content/surface-crack-detection/Positive/01577.jpg
# /content/surface-crack-detection/Positive/07282.jpg
# /content/surface-crack-detection/Positive/09739.jpg
# /content/surface-crack-detection/Positive/07919.jpg
# /content/surface-crack-detection/Positive/11849_1.jpg
# /content/surface-crack-detection/Positive/09546.jpg
# /content/surface-crack-detection/Positive/17889_1.jpg
# /content/surface-crack-detection/Positive/11729_1.jpg
# /content/surface-crack-detection/Positive/00294.jpg
# /content/surface-crack-detection/Positive/02856.jpg
# /content/surface-crack-detection/Positive/17419_1.jpg
# ...

# %%
import cv2

# %%
for filename in os.listdir(dataset):
  img_path=os.path.join(dataset,filename)

img=cv2.imread(img_path)
img=cv2.resize(img,(64,64))
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (64, 64, 3)

# %%
images=[]
labels=[]

# %%
import numpy as np

# %%
images.append(img)
labels.append(1)

# %%
print(images)
# Out:
# [array([[[193, 186, 175],
#         [188, 180, 169],
#         [154, 146, 135],
#         ...,
#         [194, 188, 183],
#         [180, 175, 169],
#         [177, 172, 166]],
#
#        [[162, 155, 144],
#         [169, 161, 150],
#         [151, 144, 133],
#         ...,
#         [189, 184, 178],
#         [173, 168, 162],
#         [171, 166, 160]],
#
#        [[161, 153, 142],
#         [159, 151, 140],
#         [182, 174, 163],
#         ...,
#         [190, 185, 179],
#         [183, 178, 172],
#         [182, 177, 171]],
#
#        ...,
#
#        [[ 68,  69,  64],
#         [ 70,  71,  66],
#         [ 69,  70,  65],
#         ...,
#         [199, 194, 188],
#         [189, 184, 178],
#         [190, 187, 180]],
#
#        [[ 68,  69,  64],
#         [ 70,  71,  66],
#         [ 72,  73,  68],
#         ...,
#         [187, 182, 176],
#         [183, 178, 172],
#         [181, 178, 171]],
#
#        [[ 71,  71,  69],
#         [ 70,  70,  69],
#         [ 75,  75,  73],
# ...

# %%
dataset_neg="/content/surface-crack-detection/Negative"

# %%
for filename in os.listdir(dataset_neg):
  imge_path=os.path.join(dataset_neg,filename)

  img=cv2.imread(imge_path)
  img=cv2.resize(img,(64,64))
  img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
  images.append(img)
  labels.append(0)
